# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv("cleandata1.csv")
data.head(10)
# Out:
#    Unnamed: 0        Date      Time  Latitude  Longitude        Type  Depth  \
# 0           0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6
# 1           1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0
# 2           2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0
# 3           3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0
# 4           4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0
# 5           5  01/10/1965  13:36:32   -13.405    166.629  Earthquake   35.0
# 6           6  01/12/1965  13:32:25    27.357     87.867  Earthquake   20.0
# 7           7  01/15/1965  23:17:42   -13.309    166.212  Earthquake   35.0
# 8           8  01/16/1965  11:32:37   -56.452    -27.043  Earthquake   95.0
# 9           9  01/17/1965  10:43:17   -24.563    178.487  Earthquake  565.0
#
#    Depth Error  Depth Seismic Stations  Magnitude  ...  \
# 0          1.8               83.472535        6.0  ...
# ...

# %%
data.shape
# Out:
# (23412, 22)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# Date                          0
# Time                          0
# Latitude                      0
# Longitude                     0
# Type                          0
# Depth                         0
# Depth Error                   0
# Depth Seismic Stations        0
# Magnitude                     0
# Magnitude Type                0
# Magnitude Error               0
# Magnitude Seismic Stations    0
# Azimuthal Gap                 0
# Horizontal Distance           0
# Horizontal Error              0
# Root Mean Square              0
# ID                            0
# Source                        0
# Location Source               0
# Magnitude Source              0
# Status                        0
# dtype: int64

# %%
data.isnull()
# Out:
#        Unnamed: 0   Date   Time  Latitude  Longitude   Type  Depth  \
# 0           False  False  False     False      False  False  False
# 1           False  False  False     False      False  False  False
# 2           False  False  False     False      False  False  False
# 3           False  False  False     False      False  False  False
# 4           False  False  False     False      False  False  False
# ...           ...    ...    ...       ...        ...    ...    ...
# 23407       False  False  False     False      False  False  False
# 23408       False  False  False     False      False  False  False
# 23409       False  False  False     False      False  False  False
# 23410       False  False  False     False      False  False  False
# 23411       False  False  False     False      False  False  False
#
#        Depth Error  Depth Seismic Stations  Magnitude  ...  \
# 0            False                   False      False  ...
# ...

# %%
x=data['Latitude']
y=data['Longitude']
plt.xlabel('Latitude',fontsize=16)
plt.ylabel('Longitude',fontsize=16)
plt.bar(x,y)
plt.show()

# %%
data.plot(x="Latitude", y="Longitude", kind="bar")
# Out:
# <Axes: xlabel='Latitude'>

# %%
plt.hist(data["Depth"])
plt.show()

# %%
print("Line graph:")

plt.xlabel('Depth Seismic Stations',fontsize=16)
plt.ylabel('Magnitude Seismic Stations',fontsize=16)
plt.scatter(x,y)
plt.show()
# Out:
# Line graph:

# %%
plt.plot(data['Magnitude'],data['Magnitude Error'], color='black', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='blue', markersize=12)

# %%
x=data['Azimuthal Gap']
y=data['Horizontal Distance']
x = np.arange(0, 2*(np.pi), 0.1)
y = np.sin(x)
plt.xlabel('Azimuthal Gap',fontsize=16)
plt.ylabel('Horizontal Distance',fontsize=16)
plt.plot(x, y)
plt.show()

# %%
x=data['Horizontal Error']
plt.xlabel('Horizontal Error')
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x787845475d50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x787845474400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7878454746a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x787845475a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x787845476ec0>],
#  'means': []}

# %%
x=data['Root Mean Square']
plt.xlabel('Root Mean Square')
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7878456d2500>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7878456d2140>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7878456d10c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7878a412fee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7878a412e200>],
#  'means': []}

# %%
x=data['Latitude']
plt.xlabel('Latitude')
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7878424fa4a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7878424f88e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7878424fa860>],
#  'medians': [<matplotlib.lines.Line2D at 0x787842ff5120>],
#  'fliers': [<matplotlib.lines.Line2D at 0x787842ff7a90>],
#  'means': []}

# %%
x=data['Magnitude']
plt.xlabel('Magnitude')
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7878420344f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x787842036770>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7878420371f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x787845e21720>],
#  'fliers': [<matplotlib.lines.Line2D at 0x787845e22fb0>],
#  'means': []}

# %%
x=data['Azimuthal Gap']
y=data['Horizontal Distance']
plt.xlabel('Azimuthal Gap',fontsize=16)
plt.ylabel('Horizontal Distance',fontsize=16)
plt.bar(x,y)
plt.show()

# %%
plt.subplot(1,2,2)
sns.boxplot(data['Depth'])
plt.show()

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data['Magnitude'])
plt.show()
# Out:
# <ipython-input-19-47b415b9377b>:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %%
fig1=plt.figure()
x1=fig1.add_axes([.1,.1,2,1])
x1.plot(data['Magnitude'])

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=data,x='Horizontal Distance',y='Magnitude')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=data,x='Latitude',y='Longitude',hue='Magnitude')
plt.show()
